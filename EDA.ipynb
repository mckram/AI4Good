# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
harms = pd.read_csv('substance_harm_data.csv')
waste = pd.read_csv('wastewater_data.csv')

# %%
harms.head()
# Out:
#   Substance  Source Specific_Measure                             Type_Event  \
# 0   Opioids  Deaths  Overall numbers  Total apparent opioid toxicity deaths
# 1   Opioids  Deaths  Overall numbers  Total apparent opioid toxicity deaths
# 2   Opioids  Deaths  Overall numbers  Total apparent opioid toxicity deaths
# 3   Opioids  Deaths  Overall numbers  Total apparent opioid toxicity deaths
# 4   Opioids  Deaths  Overall numbers  Total apparent opioid toxicity deaths
#
#    Region  PRUID Time_Period Year_Quarter Aggregator Disaggregator  \
# 0  Canada      1     By year         2016        NaN           NaN
# 1  Canada      1     By year         2016        NaN           NaN
# 2  Canada      1     By year         2016        NaN           NaN
# 3  Canada      1     By year         2017        NaN           NaN
# 4  Canada      1     By year         2017        NaN           NaN
#
#                 Unit Value
# 0         Crude rate   7.8
# 1             Number  2827
# ...

# %%
waste.head()
# Out:
#   REF_DATE                                GEO  DGUID  \
# 0   Mar-19  Weighted average, cities measured    NaN
# 1   Mar-19  Weighted average, cities measured    NaN
# 2   Mar-19  Weighted average, cities measured    NaN
# 3   Mar-19  Weighted average, cities measured    NaN
# 4   Mar-19  Weighted average, cities measured    NaN
#
#                           Measure  \
# 0  THC-COOH (Cannabis metabolite)
# 1  THC-COOH (Cannabis metabolite)
# 2  THC-COOH (Cannabis metabolite)
# 3  THC-COOH (Cannabis metabolite)
# 4  THC-COOH (Cannabis metabolite)
#
#                                      Characteristics  \
# 0  Load per capita (grams per one million people ...
# 1  Lower bound of the 95% confidence interval, lo...
# 2  Upper bound of the 95% confidence interval, lo...
# 3                    Standard error, load per capita
# 4                   Imputation rate, load per capita
#
#                                     UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID  \
# ...

# %%
waste.shape
waste.info()
waste.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11088 entries, 0 to 11087
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   REF_DATE         11088 non-null  object
#  1   GEO              11088 non-null  object
#  2   DGUID            0 non-null      float64
#  3   Measure          11088 non-null  object
#  4   Characteristics  11088 non-null  object
#  5   UOM              11088 non-null  object
#  6   UOM_ID           11088 non-null  int64
#  7   SCALAR_FACTOR    11088 non-null  object
#  8   SCALAR_ID        11088 non-null  int64
#  9   VECTOR           11088 non-null  object
#  10  COORDINATE       11088 non-null  object
#  11  VALUE            9665 non-null   float64
#  12  STATUS           2142 non-null   object
#  13  SYMBOL           0 non-null      float64
#  14  TERMINATED       0 non-null      float64
#  15  DECIMALS         11088 non-null  int64
# ...

# %%
harms.shape
harms.info()
harms.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12099 entries, 0 to 12098
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Substance         12099 non-null  object
#  1   Source            12099 non-null  object
#  2   Specific_Measure  12099 non-null  object
#  3   Type_Event        12099 non-null  object
#  4   Region            12099 non-null  object
#  5   PRUID             12099 non-null  int64
#  6   Time_Period       12099 non-null  object
#  7   Year_Quarter      12099 non-null  object
#  8   Aggregator        8161 non-null   object
#  9   Disaggregator     8161 non-null   object
#  10  Unit              12099 non-null  object
#  11  Value             11559 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.1+ MB
# Substance           object
# Source              object
# Specific_Measure    object
# Type_Event          object
# Region              object
# ...

# %%
#percentage of na
waste.isnull().sum() / waste.shape[0] * 100
# Out:
# REF_DATE             0.000000
# GEO                  0.000000
# DGUID              100.000000
# Measure              0.000000
# Characteristics      0.000000
# UOM                  0.000000
# UOM_ID               0.000000
# SCALAR_FACTOR        0.000000
# SCALAR_ID            0.000000
# VECTOR               0.000000
# COORDINATE           0.000000
# VALUE               12.833694
# STATUS              80.681818
# SYMBOL             100.000000
# TERMINATED         100.000000
# DECIMALS             0.000000
# dtype: float64

# %%
waste = waste.drop(['SYMBOL', 'TERMINATED', 'DGUID'], axis=1)

# %%
#percentage of na
harms.isnull().sum() / harms.shape[0] * 100
# Out:
# Substance            0.000000
# Source               0.000000
# Specific_Measure     0.000000
# Type_Event           0.000000
# Region               0.000000
# PRUID                0.000000
# Time_Period          0.000000
# Year_Quarter         0.000000
# Aggregator          32.548144
# Disaggregator       32.548144
# Unit                 0.000000
# Value                4.463179
# dtype: float64

# %%
print(waste.isnull().sum())
# Out:
# REF_DATE              0
# GEO                   0
# Measure               0
# Characteristics       0
# UOM                   0
# UOM_ID                0
# SCALAR_FACTOR         0
# SCALAR_ID             0
# VECTOR                0
# COORDINATE            0
# VALUE              1423
# STATUS             8946
# DECIMALS              0
# dtype: int64

# %%
print(harms.isnull().sum())
# Out:
# Substance              0
# Source                 0
# Specific_Measure       0
# Type_Event             0
# Region                 0
# PRUID                  0
# Time_Period            0
# Year_Quarter           0
# Aggregator          3938
# Disaggregator       3938
# Unit                   0
# Value                540
# dtype: int64
