# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
from sklearn.model_selection import train_test_split
# %matplotlib inline 
sns.set(color_codes=True)

# %%
data = pd.read_csv('tedsa_puf_2018.csv')

# %%
data.head()
# Out:
#    ADMYR       CASEID  STFIPS  CBSA2010  EDUC  MARSTAT  SERVICES  DETCRIM  \
# 0   2018  20181823904       2        -9     3        1         2       -9
# 1   2018  20182001271       2     11260     3        1         7       -9
# 2   2018  20181622919       2        -9     3        1         4       -9
# 3   2018  20181626210       2     11260     2        1         6       -9
# 4   2018  20182034958       2        -9     3        1         4       -9
#
#    NOPRIOR  PSOURCE  ...  TRNQFLG  BARBFLG  SEDHPFLG  INHFLG  OTCFLG  \
# 0        0        1  ...        0        0         0       0       0
# 1        1       -9  ...        0        0         0       0       0
# 2        1        1  ...        0        0         0       0       0
# 3        0        6  ...        0        0         0       0       0
# 4        0        1  ...        0        0         0       0       0
#
#    OTHERFLG  DIVISION  REGION  IDU  ALCDRUG
# 0         0         9       4    1        2
# ...

# %%
data1 = pd.read_csv('tedsd_puf_2019.csv')

# %%
data.shape
# Out:
# (2060509, 62)

# %%
data.columns
# Out:
# Index(['ADMYR', 'CASEID', 'STFIPS', 'CBSA2010', 'EDUC', 'MARSTAT', 'SERVICES',
#        'DETCRIM', 'NOPRIOR', 'PSOURCE', 'ARRESTS', 'EMPLOY', 'METHUSE',
#        'PSYPROB', 'PREG', 'GENDER', 'VET', 'LIVARAG', 'DAYWAIT', 'DSMCRIT',
#        'AGE', 'RACE', 'ETHNIC', 'DETNLF', 'PRIMINC', 'SUB1', 'SUB2', 'SUB3',
#        'ROUTE1', 'ROUTE2', 'ROUTE3', 'FREQ1', 'FREQ2', 'FREQ3', 'FRSTUSE1',
#        'FRSTUSE2', 'FRSTUSE3', 'HLTHINS', 'PRIMPAY', 'FREQ_ATND_SELF_HELP',
#        'ALCFLG', 'COKEFLG', 'MARFLG', 'HERFLG', 'METHFLG', 'OPSYNFLG',
#        'PCPFLG', 'HALLFLG', 'MTHAMFLG', 'AMPHFLG', 'STIMFLG', 'BENZFLG',
#        'TRNQFLG', 'BARBFLG', 'SEDHPFLG', 'INHFLG', 'OTCFLG', 'OTHERFLG',
#        'DIVISION', 'REGION', 'IDU', 'ALCDRUG'],
#       dtype='object')

# %%
newData = data.loc[data['SUB1'].isin([5,6, 7])]
newData = data.loc[data['SUB2'].isin([5,6, 7])]
newData.head()
# Out:
#     ADMYR       CASEID  STFIPS  CBSA2010  EDUC  MARSTAT  SERVICES  DETCRIM  \
# 7    2018  20181691844       6     41740     3       -9         7       -9
# 12   2018  20181871438       2     11260     3        3         7       -9
# 16   2018  20181814170       2        -9     2        1         7       -9
# 48   2018  20181983747       2     11260     4        1         6       -9
# 87   2018  20181868350       2     11260    -9        2         6        3
#
#     NOPRIOR  PSOURCE  ...  TRNQFLG  BARBFLG  SEDHPFLG  INHFLG  OTCFLG  \
# 7         0        1  ...        0        0         0       0       0
# 12        0        1  ...        0        0         0       0       0
# 16        0        1  ...        0        0         0       0       0
# 48        2        1  ...        0        0         0       0       0
# 87        2        7  ...        0        0         0       0       0
#
#     OTHERFLG  DIVISION  REGION  IDU  ALCDRUG
# 7          0         9       4    0        2
# ...

# %%
#not needed, ADMYR, STFIPS, CBSA2010, REGION, DIVISION, DAYWAIT, SUB 1-3, ROUTE 1-3, FREQ1-3, FRTUSE 1-3
nD = newData.drop(columns=['ADMYR', 'STFIPS', 'CBSA2010', 'REGION', 'DIVISION', 'DAYWAIT', 'SUB1','SUB2', 'SUB3', 'ROUTE2', 'ROUTE3', 'FREQ2', 'FREQ3'])
nD.head()
# Out:
#          CASEID  EDUC  MARSTAT  SERVICES  DETCRIM  NOPRIOR  PSOURCE  ARRESTS  \
# 7   20181691844     3       -9         7       -9        0        1        0
# 12  20181871438     3        3         7       -9        0        1        1
# 16  20181814170     2        1         7       -9        0        1        0
# 48  20181983747     4        1         6       -9        2        1        0
# 87  20181868350    -9        2         6        3        2        7        0
#
#     EMPLOY  METHUSE  ...  STIMFLG  BENZFLG  TRNQFLG  BARBFLG  SEDHPFLG  \
# 7        4        1  ...        0        0        0        0         0
# 12       3        2  ...        0        0        0        0         0
# 16       2        2  ...        0        0        0        0         0
# 48       4        1  ...        0        0        0        0         0
# 87       3        2  ...        0        0        0        0         0
#
#     INHFLG  OTCFLG  OTHERFLG  IDU  ALCDRUG
# ...

# %%
nD.shape
# Out:
# (142437, 49)

# %%
nD.columns
# Out:
# Index(['CASEID', 'EDUC', 'MARSTAT', 'SERVICES', 'DETCRIM', 'NOPRIOR',
#        'PSOURCE', 'ARRESTS', 'EMPLOY', 'METHUSE', 'PSYPROB', 'PREG', 'GENDER',
#        'VET', 'LIVARAG', 'DSMCRIT', 'AGE', 'RACE', 'ETHNIC', 'DETNLF',
#        'PRIMINC', 'ROUTE1', 'FREQ1', 'FRSTUSE1', 'FRSTUSE2', 'FRSTUSE3',
#        'HLTHINS', 'PRIMPAY', 'FREQ_ATND_SELF_HELP', 'ALCFLG', 'COKEFLG',
#        'MARFLG', 'HERFLG', 'METHFLG', 'OPSYNFLG', 'PCPFLG', 'HALLFLG',
#        'MTHAMFLG', 'AMPHFLG', 'STIMFLG', 'BENZFLG', 'TRNQFLG', 'BARBFLG',
#        'SEDHPFLG', 'INHFLG', 'OTCFLG', 'OTHERFLG', 'IDU', 'ALCDRUG'],
#       dtype='object')

# %%
#NEED TO ONE HOT ENCODE ALL COLUMNS EXCEPT FLG 
def onehot(df, column):
    df = pd.concat([df,pd.get_dummies(df[column], prefix=column)],axis=1)
    df.drop([column],axis=1, inplace=True)
    return df

new = onehot(nD, 'EDUC')
new = onehot(new, 'MARSTAT')
new = onehot(new, 'SERVICES')
new = onehot(new, 'DETCRIM')
new = onehot(new, 'NOPRIOR')
new = onehot(new, 'PSOURCE')
new = onehot(new, 'ARRESTS')
new = onehot(new, 'EMPLOY')
new = onehot(new, 'METHUSE')
new = onehot(new, 'PSYPROB')
new = onehot(new, 'PREG')
new = onehot(new, 'GENDER')
new = onehot(new, 'VET')
new = onehot(new, 'LIVARAG')
new = onehot(new, 'DSMCRIT')
new = onehot(new, 'AGE')
new = onehot(new, 'RACE')
new = onehot(new, 'ETHNIC')
new = onehot(new, 'DETNLF')
new = onehot(new, 'PRIMINC')
new = onehot(new, 'HLTHINS')
new = onehot(new, 'PRIMPAY')
new = onehot(new, 'FREQ_ATND_SELF_HELP')
new = onehot(new, 'IDU')
new = onehot(new, 'ROUTE1')
new = onehot(new, 'FREQ1')

new.head()
# Out:
#          CASEID  FRSTUSE1  FRSTUSE2  FRSTUSE3  ALCFLG  COKEFLG  MARFLG  \
# 7   20181691844         7         7        -9       0        0       0
# 12  20181871438         5         4         2       1        0       0
# 16  20181814170         5         5        -9       0        0       0
# 48  20181983747         7         6        -9       0        1       0
# 87  20181868350         6         6         1       1        0       0
#
#     HERFLG  METHFLG  OPSYNFLG  ...  ROUTE1_-9  ROUTE1_1  ROUTE1_2  ROUTE1_3  \
# 7        1        0         1  ...          0         0         1         0
# 12       1        0         1  ...          0         0         0         0
# 16       1        0         0  ...          0         0         0         0
# 48       0        0         1  ...          0         0         1         0
# 87       1        0         0  ...          0         0         0         0
#
#     ROUTE1_4  ROUTE1_5  FREQ1_-9  FREQ1_1  FREQ1_2  FREQ1_3
# ...

# %%
data1.columns
# Out:
# Index(['DISYR', 'CASEID', 'STFIPS', 'CBSA2010', 'EDUC', 'MARSTAT', 'SERVICES',
#        'DETCRIM', 'LOS', 'PSOURCE', 'NOPRIOR', 'ARRESTS', 'EMPLOY', 'METHUSE',
#        'PSYPROB', 'PREG', 'GENDER', 'VET', 'LIVARAG', 'DAYWAIT', 'SERVICES_D',
#        'REASON', 'EMPLOY_D', 'LIVARAG_D', 'ARRESTS_D', 'DSMCRIT', 'AGE',
#        'RACE', 'ETHNIC', 'DETNLF', 'DETNLF_D', 'PRIMINC', 'SUB1', 'SUB2',
#        'SUB3', 'SUB1_D', 'SUB2_D', 'SUB3_D', 'ROUTE1', 'ROUTE2', 'ROUTE3',
#        'FREQ1', 'FREQ2', 'FREQ3', 'FREQ1_D', 'FREQ2_D', 'FREQ3_D', 'FRSTUSE1',
#        'FRSTUSE2', 'FRSTUSE3', 'HLTHINS', 'PRIMPAY', 'FREQ_ATND_SELF_HELP',
#        'FREQ_ATND_SELF_HELP_D', 'ALCFLG', 'COKEFLG', 'MARFLG', 'HERFLG',
#        'METHFLG', 'OPSYNFLG', 'PCPFLG', 'HALLFLG', 'MTHAMFLG', 'AMPHFLG',
#        'STIMFLG', 'BENZFLG', 'TRNQFLG', 'BARBFLG', 'SEDHPFLG', 'INHFLG',
#        'OTCFLG', 'OTHERFLG', 'DIVISION', 'REGION', 'IDU', 'ALCDRUG'],
#       dtype='object')

# %%
data1.drop(data1.columns.difference(['CASEID','REASON']), 1, inplace=True)
# Out:
# /var/folders/41/nq0wbhf57nqgnnnt31cc9j4m0000gn/T/ipykernel_51318/2965572001.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data1.drop(data1.columns.difference(['CASEID','REASON']), 1, inplace=True)

# %%
data1.head()
# Out:
#         CASEID  REASON
# 0  20191553576       1
# 1  20191465214       3
# 2  20191443889       3
# 3  20191409377       1
# 4  20191479567       3

# %%
new['CASEID'] = new['CASEID'].astype("string")
data1['CASEID'] = data1['CASEID'].astype("string")

new['CASEID'] = new['CASEID'].str[4:]
data1['CASEID'] = data1['CASEID'].str[4:]

# %%
finalData = pd.merge(new, data1, on="CASEID")

# %%
finalData.head()
# Out:
#     CASEID  FRSTUSE1  FRSTUSE2  FRSTUSE3  ALCFLG  COKEFLG  MARFLG  HERFLG  \
# 0  1691844         7         7        -9       0        0       0       1
# 1  1706506         4         4         3       1        0       0       1
# 2  1759402         3         3         3       1        0       0       1
# 3  1640334         1         5         4       1        0       0       1
# 4  1614136         4        -9        -9       1        0       0       1
#
#    METHFLG  OPSYNFLG  ...  ROUTE1_1  ROUTE1_2  ROUTE1_3  ROUTE1_4  ROUTE1_5  \
# 0        0         1  ...         0         1         0         0         0
# 1        0         0  ...         0         1         0         0         0
# 2        0         0  ...         0         0         0         1         0
# 3        0         0  ...         1         0         0         0         0
# 4        0         0  ...         1         0         0         0         0
#
#    FREQ1_-9  FREQ1_1  FREQ1_2  FREQ1_3  REASON
# ...

# %%
finalData.shape
# Out:
# (126648, 186)

# %%
# Labels are the values we want to predict
labels = np.array(finalData['REASON'])
# Remove the labels from the features
# axis 1 refers to the columns
features= finalData.drop('REASON', axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [85], in <cell line: 11>()
#       8 # Convert to numpy array
#       9 features = np.array(features)
# ---> 11 features.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (94986, 185)
# Training Labels Shape: (94986,)
# Testing Features Shape: (31662, 185)
# Testing Labels Shape: (31662,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
